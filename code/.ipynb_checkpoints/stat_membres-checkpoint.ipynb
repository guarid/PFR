# %%
import pandas as pd
import numpy as np
from os.path import join
import matplotlib.pyplot as plt

# %%
#Chargement des données
path_raw = '/Users/hermann-kevin/Desktop/PFR/data/raw_data/'
file_members = 'members.csv'

# %%
members = pd.read_csv(join(path_raw, file_members), error_bad_lines=False)

# %%
print("Nombre total de membres: {}".format(members.shape[0]) )
members.head(10)
# Out:
# Nombre total de membres: 34403
#                                            msno  city  bd  gender  \
# 0  XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=     1   0     NaN
# 1  UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=     1   0     NaN
# 2  D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=     1   0     NaN
# 3  mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=     1   0     NaN
# 4  q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=     1   0     NaN
# 5  zgPOEyUn5a/Fvuzb3m69ajzxjkbblVtObglW89FzLdo=    13  43  female
# 6  Sw9AT8QoR4wWiNUqHZUH6g5ahzGUx4lo1g+Y3xE2f2M=     1   0     NaN
# 7  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY=     1   0     NaN
# 8  kfk1AdTNH2dNqF5LzIs4e0vwGPejw2jrnFjJlcYnEgk=     1   0     NaN
# 9  tscijwx4dbEp0NXGl+iFtHJ8zrj+TkcMrduOQk9t+gE=     1   0     NaN
#
#    registered_via  registration_init_time  expiration_date
# 0               7                20110820         20170920
# 1               7                20150628         20170622
# 2               4                20160411         20170712
# 3               9                20150906         20150907
# 4               4                20170126         20170613
# 5               9                20120703         20171006
# 6               4                20160326         20160329
# 7               7                20160130         20170930
# 8               7                20110111         20170930
# 9               7                20160217         20170613

# %%
from collections import Counter
print("*****Nombre d'utilisateurs par ville*****")

freqC = Counter(members['city'])
dfC = pd.DataFrame.from_dict(freqC, orient='index').sort_values(by=[0], ascending=False).reset_index()
dfC.columns= ['Ville', 'Nombre d\'utilisateurs']
dfC
# Out:
# *****Nombre d'utilisateurs par ville*****
#     Ville  Nombre d'utilisateurs
# 0       1                  19445
# 1      13                   3395
# 2       5                   2634
# 3       4                   1732
# 4      15                   1525
# 5      22                   1467
# 6       6                    913
# 7      14                    708
# 8      12                    491
# 9       9                    309
# 10      8                    289
# 11     11                    285
# 12     18                    259
# 13     10                    216
# 14     21                    213
# 15      3                    204
# 16     17                    152
# 17      7                     93
# 18     16                     35
# 19     20                     27
# 20     19                     11

# %% [markdown]
# #### On remarque que la majorité des utilisateurs sont issues de la ville 1. On peut donc séparer les utilisateurs en deux catégories, ceux issus de la ville 1 et ceux qui ne le sont pas

# %%
print("*****Age des utilisateurs par ordre décroissant*****")

freqA = Counter(members['bd'])
dfA = pd.DataFrame.from_dict(freqA, orient='index').sort_values(by=[0], ascending=False).reset_index()
dfA.columns= ['Age', 'Nombre d\'utilisateurs']
dfA
# Out:
# *****Age des utilisateurs par ordre décroissant*****
#      Age  Nombre d'utilisateurs
# 0      0                  19932
# 1     22                    751
# 2     27                    750
# 3     24                    740
# 4     26                    719
# 5     25                    716
# 6     23                    712
# 7     28                    688
# 8     21                    685
# 9     29                    661
# 10    20                    631
# 11    30                    602
# 12    19                    507
# 13    31                    491
# 14    32                    466
# 15    18                    466
# 16    33                    416
# 17    34                    404
# 18    17                    398
# 19    35                    380
# 20    36                    341
# 21    37                    300
# 22    38                    294
# 23    39                    226
# 24    16                    215
# 25    40                    204
# 26    41                    194
# 27    44                    138
# 28    42                    131
# 29    43                    121
# ..   ...                    ...
# 65     5                      2
# 66  1051                      1
# 67    87                      1
# 68     7                      1
# 69    95                      1
# 70    78                      1
# 71   -43                      1
# 72    93                      1
# 73   107                      1
# 74    11                      1
# 75   106                      1
# 76  1030                      1
# 77    82                      1
# 78    89                      1
# 79    96                      1
# 80    85                      1
# 81   144                      1
# 82   -38                      1
# 83   931                      1
# 84    70                      1
# 85   131                      1
# 86    12                      1
# 87    90                      1
# 88     2                      1
# 89     3                      1
# 90    97                      1
# 91    76                      1
# 92   103                      1
# 93   101                      1
# 94    10                      1
#
# [95 rows x 2 columns]

# %% [markdown]
# #### On remarque qu'on ne connaît pas l'age pour la majorité des utilisateurs. On a plus de la moitié des valeurs qui sont aberrantes (age=0 et age >= 100)

# %%
print("*****Age des utilisateurs par ville*****")
plt.bar(members['city'], members['bd'])
plt.show()
# Out:
# *****Age des utilisateurs par ville*****
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3fdce8d3431f> in <module>()
#       1 print("*****Age des utilisateurs par ville*****")
# ----> 2 plt.bar(members['city'], members['bd'])
#       3 plt.show()
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in bar(left, height, width, bottom, hold, data, **kwargs)
#    2702     try:
#    2703         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2704                      **kwargs)
#    2705     finally:
#    2706         ax._hold = washold
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, left, height, width, bottom, **kwargs)
#    2126             elif orientation == 'horizontal':
#    2127                 r.sticky_edges.x.append(l)
# -> 2128             self.add_patch(r)
#    2129             patches.append(r)
#    2130
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in add_patch(self, p)
#    1866         if p.get_clip_path() is None:
#    1867             p.set_clip_path(self.patch)
# -> 1868         self._update_patch_limits(p)
#    1869         self.patches.append(p)
#    1870         p._remove_method = lambda h: self.patches.remove(h)
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _update_patch_limits(self, patch)
#    1893
#    1894             updatex, updatey = patch.get_transform().\
# -> 1895                 contains_branch_seperately(self.transData)
#    1896             self.update_datalim(xys, updatex=updatex,
#    1897                                 updatey=updatey)
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/transforms.py in contains_branch_seperately(self, other_transform)
#    1260         # for a non-blended transform each seperate dimension is the same, so
#    1261         # just return the appropriate shape.
# -> 1262         return [self.contains_branch(other_transform)] * 2
#    1263
#    1264     def __sub__(self, other):
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/transforms.py in contains_branch(self, other)
#    1239
#    1240         # check that a subtree is equal to other (starting from self)
# -> 1241         for _, sub_tree in self._iter_break_from_left_to_right():
#    1242             if sub_tree == other:
#    1243                 return True
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/transforms.py in _iter_break_from_left_to_right(self)
#    2343     def _iter_break_from_left_to_right(self):
#    2344         for lh_compliment, rh_compliment in self._a._iter_break_from_left_to_right():
# -> 2345             yield lh_compliment, rh_compliment + self._b
#    2346         for lh_compliment, rh_compliment in self._b._iter_break_from_left_to_right():
#    2347             yield self._a + lh_compliment, rh_compliment
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/transforms.py in __add__(self, other)
#    1177         """
#    1178         if isinstance(other, Transform):
# -> 1179             return composite_transform_factory(self, other)
#    1180         raise TypeError(
#    1181             "Can not add Transform to object of type '%s'" % type(other))
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/transforms.py in composite_transform_factory(a, b)
#    2493     elif isinstance(a, Affine2D) and isinstance(b, Affine2D):
#    2494         return CompositeAffine2D(a, b)
# -> 2495     return CompositeGenericTransform(a, b)
#    2496
#    2497
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/transforms.py in __init__(self, a, b, **kwargs)
#    2305         self.output_dims = b.output_dims
#    2306
# -> 2307         Transform.__init__(self, **kwargs)
#    2308         self._a = a
#    2309         self._b = b
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/transforms.py in __init__(self, shorthand_name)
#      97         # parents are deleted, references from the children won't keep
#      98         # them alive.
# ---> 99         self._parents = WeakValueDictionary()
#     100
#     101         # TransformNodes start out as invalid until their values are
#
# /anaconda3/lib/python3.6/weakref.py in __init__(*args, **kw)
#     121         self._iterating = set()
#     122         self.data = d = {}
# --> 123         self.update(*args, **kw)
#     124
#     125     def _commit_removals(self):
#
# /anaconda3/lib/python3.6/weakref.py in update(*args, **kwargs)
#     286             return o
#     287
# --> 288     def update(*args, **kwargs):
#     289         if not args:
#     290             raise TypeError("descriptor 'update' of 'WeakValueDictionary' "
#
# KeyboardInterrupt:

# %%
print("*****Genre des utilisateurs*****")

freqG = Counter(members['gender'])
dfG = pd.DataFrame.from_dict(freqG, orient='index').sort_values(by=[0], ascending=False).reset_index()
dfG.columns= ['Genre', 'Nombre d\'utilisateurs']
dfG
# Out:
# *****Genre des utilisateurs*****
#     Genre  Nombre d'utilisateurs
# 0     NaN                  19902
# 1    male                   7405
# 2  female                   7096

# %% [markdown]
# #### Comme pour le genre, on remarque qu'on ne connaît pas le genre pour 58% des utilisateurs. On a donc une majorité des utilisateurs pour lesquels il manque cette information.

# %%
print("*****Différents types d'enregistrement des utilisateurs*****")
freqR = Counter(members['registered_via'])
dfR = pd.DataFrame.from_dict(freqR, orient='index').reset_index()
plt.pie(dfR[0], labels=dfR['index'])
plt.show()
# Out:
# *****Différents types d'enregistrement des utilisateurs*****
